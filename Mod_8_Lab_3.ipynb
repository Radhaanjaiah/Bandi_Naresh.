# %% [markdown]
# <a href="https://colab.research.google.com/github/Radhaanjaiah/fmml_course_assingnment/blob/main/Mod_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-27 17:06:06--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  73.6MB/s    in 0.9s
#
# 2024-03-27 17:06:07 (73.6 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 15188  1612.00866v1  The generation of political event data has rem...    cs
# 27699  1704.02899v1  Single particle cryo-electron microscopy (EM) ...    cs
# 22397  1605.07870v1  Dictionary learning is a cutting-edge area in ...  stat
# 3161    1309.5427v1  Linear Discriminant Analysis (LDA) is a well-k...    cs
# 7209   1711.01297v1  We interpret HyperNetworks within the framewor...  stat
# ...             ...                                                ...   ...
# 7784   1803.03756v1  In bankruptcy prediction, the proportion of ev...  stat
# 22801  1707.02461v2  Given full or partial information about a coll...  stat
# 5448    1210.5873v1  The performance of the Self-Organizing Map (SO...  stat
# 22015   1311.2520v3  In Stochastic blockmodels, which are among the...  stat
# 11307  1508.04757v1  In this paper, we propose a technique for time...  stat
#
#                                                    title  year  \
# 15188   Creating a Real-Time, Reproducible Event Dataset  2016
# 27699  Continuously heterogeneous hyper-objects in cr...  2017
# 22397  Simultaneous Sparse Dictionary Learning and Pr...  2016
# 3161                 Latent Fisher Discriminant Analysis  2013
# 7209      Implicit Weight Uncertainty in Neural Networks  2017
# ...                                                  ...   ...
# 7784   Influence of the Event Rate on Discrimination ...  2018
# 22801  Subspace Clustering with Missing and Corrupted...  2017
# 5448   Initialization of Self-Organizing Maps: Princi...  2012
# 22015  The Infinite Degree Corrected Stochastic Block...  2013
# 11307  Time Series Clustering via Community Detection...  2015
#
#                                                 keywords
# 15188  [generation, political, acquisition, significa...
# 27699  [microscopy, increasingly, determining, struct...
# 22397  [dictionary, processing, processing, decomposi...
# 3161   [discriminant, dimensionality, reduction, clas...
# 7209   [interpret, hypernetworks, framework, variatio...
# ...                                                  ...
# 7784   [bankruptcy, prediction, proportion, oversampl...
# 22801  [information, collection, subspaces, clusterin...
# 5448   [performance, organizing, algorithm, dependent...
# 22015  [stochastic, blockmodels, prominent, statistic...
# 11307  [technique, clustering, community, detection, ...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 15188    [generation, political, acquisition, significa...
# 27699    [microscopy, increasingly, determining, struct...
# 22397    [dictionary, processing, processing, decomposi...
# 3161     [discriminant, dimensionality, reduction, clas...
# 7209     [interpret, hypernetworks, framework, variatio...
#                                ...
# 24       [remarkably, successful, perceptual, vulnerabl...
# 39772    [addresses, automatic, summarization, comprisi...
# 6069     [prediction, anopheles, environmental, variabl...
# 20151    [probability, conditioned, variables, algorith...
# 22138    [structure, variables, observations, modelling...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8719 words.
# Out of those 4531 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="dd4368ad-dbf2-4128-b852-73813106f7d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd4368ad-dbf2-4128-b852-73813106f7d0")) {                    Plotly.newPlot(                        "dd4368ad-dbf2-4128-b852-73813106f7d0",                        [{"x":["underlying","significant","examining","integrated","digitized","necessary","comparison","generation","political","reproducible","acquisition","processing","availability","collection","improvements","dimensional","increasingly","introduced","algorithm","opportunities","reconstruct","continuum","experiment","operations","simulated","interesting","determining","reconstruction","dimensions","structures","conformations","principle","heterogeneous","microscopy","continuously","represent","generalize","manuscript","molecules","prototype","algorithms","positions","orientations","macromolecules","structure","presented","approaches","alternative","experimental","appropriate","decomposition","direction","dictionary","denoising","efficient","regularization","optimization","completed","precision","simultaneous","multipliers","arbitrarily","efficiency","decomposes","simultaneously","deviation","dimension","meaningful","applications","consistently","detection","competitive","extraction","inference","variables","discriminant","limitation","dimensionality","supervised","incorporates","classification","semantically","demonstrate","consistent","demonstrates","framework","baselines","reduction","challenging","evaluation","interpret","predictive","hypernetworks","performance","likelihood","distributions","comparable","variational","providing","experiments","uncertainties","distribution","uncertainty","application","experimenting","multispectral","different","validation","facilitate","selection","functions","guidelines","experimentation","management","standardize","associated","recommendations","partitioning","documentation","objective","partitioned","repository","proposals","procedure","annotations","recurrent","questions","outperforms","answering","extensive","significantly","introduce","understanding","generated","uncovering","corresponding","embeddings","respective","subsequently","additional","representation","embedding","performed","separately","modalities","individual","constrained","generative","minimizing","independent","conditional","extracting","extracted","attributes","relationships","probability","distributed","logarithmic","conjunctions","concentrated","separators","appealing","quantities","including","especially","additionally","important","distributional","considering","differential","communication","complexity","perceptron","dependence","fundamental","processes","behavioral","environments","combining","researchers","automated","successful","linguistic","characteristics","information","productive","computational","sequential","techniques","discussion","detecting","interpersonal","collaboration","engagement","participants","contributions","specifically","coordination","interactions","individuals"],"y":[108,247,9,56,5,72,138,149,11,5,37,259,22,62,131,188,42,134,826,13,34,5,88,58,54,58,35,100,50,147,1,66,37,8,18,114,44,7,7,27,623,25,9,2,340,179,413,91,372,86,74,58,58,39,412,79,329,10,76,34,14,20,173,8,102,6,64,60,401,31,336,127,143,199,125,13,29,55,191,28,529,40,561,100,55,565,52,90,245,263,17,42,0,866,54,123,107,50,89,592,9,200,77,266,6,8,716,52,43,168,198,13,17,48,3,132,20,14,6,172,9,17,30,133,84,144,63,281,71,152,284,341,153,175,5,118,75,17,24,116,362,108,143,34,38,118,70,111,43,119,90,70,101,62,58,162,92,11,5,5,4,15,18,245,109,62,342,21,61,25,57,255,18,13,83,106,16,81,95,71,109,77,75,84,701,2,301,87,388,36,54,2,7,8,24,46,158,17,68,40],"type":"bar"},{"x":["underlying","sig ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4531,), (4531, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8083333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>to</span> <span style=''>Cluster</span> <span style=''>for</span> <span style=''>Proposal</span> <span style=''>Free</span> <span style=''>Instance</span> <span style='background-color:rgba(0, 255, 0, 0.7021276595744681);'>Segmentation</span> <br/><br/><span style=''>This</span> <span style=''>work</span> <span style=''>proposed</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>to</span> <span style=''>train</span> <span style=''>a</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style=''>image</span> <span style=''>pixel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>We</span> <span style=''>applied</span> <span style=''>the</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>instance</span> <span style='background-color:rgba(0, 255, 0, 0.7021276595744681);'>segmentation</span> <span style=''>which</span> <span style=''>is</span> <span style=''>at</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5238095238095238);'>intersection</span> <span style=''>of</span> <span style=''>image</span> <span style=''>semantic</span> <span style='background-color:rgba(0, 255, 0, 0.7021276595744681);'>segmentation</span> <span style=''>and</span> <span style=''>object</span> <span style='background-color:rgba(0, 255, 0, 0.47045951859956237);'>detection</span> <span style=''>We</span> <span style=''>utilize</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fundamental</span> <span style=''>property</span> <span style=''>of</span> <span style=''>instance</span> <span style=''>labeling</span> <span style=''>the</span> <span style=''>pairwise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationship</span> <span style=''>between</span> <span style=''>pixels</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>supervision</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulate</span> <span style=''>the</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>then</span> <span style=''>apply</span> <span style=''>it</span> <span style=''>to</span> <span style=''>train</span> <span style=''>a</span> <span style=''>fully</span> <span style='background-color:rgba(0, 255, 0, 0.642691415313225);'>convolutional</span> <span style=''>network</span> <span style=''>(FCN)</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>pixel</span> <span style=''>wise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style=''>clusters</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>as</span> <span style=''>the</span> <span style=''>instance</span> <span style=''>labeling</span> <span style=''>directly</span> <span style=''>To</span> <span style=''>support</span> <span style=''>labeling</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>unlimited</span> <span style=''>number</span> <span style=''>of</span> <span style=''>instance</span> <span style=''>we</span> <span style=''>further</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulate</span> <span style=''>ideas</span> <span style=''>from</span> <span style=''>graph</span> <span style=''>coloring</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Spectral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>for</span> <span style=''>HMMs</span> <br/><br/><span style=''>Hidden</span> <span style=''>Markov</span> <span style=''>Models</span> <span style=''>(HMMs)</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accurately</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximated</span> <span style=''>using</span> <span style=''>co</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>occurrence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frequencies</span> <span style=''>of</span> <span style=''>pairs</span> <span style=''>and</span> <span style=''>triples</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>by</span> <span style=''>using</span> <span style=''>a</span> <span style=''>fast</span> <span style=''>spectral</span> <span style=''>method</span> <span style=''>in</span> <span style=''>contrast</span> <span style=''>to</span> <span style=''>the</span> <span style=''>usual</span> <span style=''>slow</span> <span style=''>methods</span> <span style=''>like</span> <span style=''>EM</span> <span style=''>or</span> <span style=''>Gibbs</span> <span style=''>sampling</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>new</span> <span style=''>spectral</span> <span style=''>method</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>reduces</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>that</span> <span style=''>need</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generates</span> <span style=''>a</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>that</span> <span style=''>does</span> <span style=''>not</span> <span style=''>depend</span> <span style=''>on</span> <span style=''>the</span> <span style=''>size</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>vocabulary</span> <span style=''>We</span> <span style=''>present</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>elementary</span> <span style=''>proof</span> <span style=''>giving</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style=''>relative</span> <span style=''>accuracy</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimates</span> <span style=''>from</span> <span style=''>our</span> <span style=''>model</span> <span style=''>(Correlaries</span> <span style=''>show</span> <span style=''>our</span> <span style=''>bounds</span> <span style=''>can</span> <span style=''>be</span> <span style=''>weakened</span> <span style=''>to</span> <span style=''>provide</span> <span style=''>either</span> <span style=''>L1</span> <span style=''>bounds</span> <span style=''>or</span> <span style=''>KL</span> <span style=''>bounds</span> <span style=''>which</span> <span style=''>provide</span> <span style=''>easier</span> <span style=''>direct</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparisons</span> <span style=''>to</span> <span style=''>previous</span> <span style=''>work)</span> <span style=''>Our ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Copula</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Component</span> <span style=''>Analysis</span> <br/><br/><span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>named</span> <span style=''>Copula</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Component</span> <span style=''>Analysis</span> <span style=''>(CCA)</span> <span style=''>for</span> <span style=''>blind</span> <span style=''>source</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separation</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Independent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Component</span> <span style=''>Analysis</span> <span style=''>(ICA)</span> <span style=''>It</span> <span style=''>differs</span> <span style=''>from</span> <span style=''>ICA</span> <span style=''>which</span> <span style=''>assumes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independence</span> <span style=''>of</span> <span style=''>sources</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>may</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependent</span> <span style=''>with</span> <span style=''>certain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>represented</span> <span style=''>by</span> <span style=''>Copula</span> <span style=''>By</span> <span style='background-color:rgba(0, 255, 0, 0.36170212765957444);'>incorporating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependency</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>much</span> <span style=''>accurate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>can</span> <span style=''>be</span> <span style=''>made</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>in</span> <span style=''>the</span> <span style=''>case</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independence</span> <span style=''>is</span> <span style=''>invalidated</span> <span style=''>A</span> <span style=''>two</span> <span style=''>phrase</span> <span style='background-color:rgba(255, 0, 0, 0.34431630971993415);'>inference</span> <span style=''>method</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>for</span> <span style=''>CCA</span> <span style=''>which</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>notion</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multidimensional</span> <span style=''>ICA</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Representations</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Counterfactual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Observational</span> <span style=''>studies</span> <span style=''>are</span> <span style=''>rising</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importance</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>widespread</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accumulation</span> <span style=''>of</span> <span style=''>data</span> <span style=''>in</span> <span style=''>fields</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>healthcare</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>education</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>employment</span> <span style=''>and</span> <span style=''>ecology</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>task</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>answering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>counterfactual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>questions</span> <span style=''>such</span> <span style=''>as</span> <span style=''>Would</span> <span style=''>this</span> <span style=''>patient</span> <span style=''>have</span> <span style=''>lower</span> <span style=''>blood</span> <span style=''>sugar</span> <span style=''>had</span> <span style=''>she</span> <span style=''>received</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>medication</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithmic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>counterfactual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>which</span> <span style=''>brings</span> <span style=''>together</span> <span style=''>ideas</span> <span style=''>from</span> <span style=''>domain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adaptation</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>learning</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>justification</span> <span style=''>we</span> <span style=''>perform</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>with</span> <span style=''>previous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style=''>causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observational</span> <span style=''>data</span> <span style=''>Our</span> <span style=''>deep</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>outperforms</span> <span style=''>the< ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09396212933190425)
# 	representation (0.1293319042515184)
# 	architecture (0.08252947481243302)
# 	knowledge (0.1264737406216506)
# 	segmentation (0.07145409074669525)
# 	detection (0.12004287245444802)
# 	information (0.25044658806716685)
# 	different (0.255805644873169)
# 	convolutional (0.1264737406216506)
# 	recognition (0.1307609860664523)
#
# Some Statistics words are:
# 	variables (0.13393303348325838)
# 	stochastic (0.13543228385807096)
# 	estimation (0.1679160419790105)
# 	statistical (0.1584207896051974)
# 	theoretical (0.15292353823088456)
# 	algorithm (0.3953023488255872)
# 	distribution (0.19140429785107446)
# 	dimensional (0.19140429785107446)
# 	inference (0.20389805097451275)
# 	regression (0.1809095452273863)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c7b3e980-6a68-4fc6-9d0c-5e862f27f5a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7b3e980-6a68-4fc6-9d0c-5e862f27f5a9")) {                    Plotly.newPlot(                        "c7b3e980-6a68-4fc6-9d0c-5e862f27f5a9",                        [{"x":["underlying","significant","examining","integrated","digitized","necessary","comparison","generation","political","reproducible","acquisition","processing","availability","collection","improvements","dimensional","increasingly","introduced","algorithm","opportunities","reconstruct","continuum","experiment","operations","simulated","interesting","determining","reconstruction","dimensions","structures","conformations","principle","heterogeneous","microscopy","continuously","represent","generalize","manuscript","molecules","prototype","algorithms","positions","orientations","macromolecules","structure","presented","approaches","alternative","experimental","appropriate","decomposition","direction","dictionary","denoising","efficient","regularization","optimization","completed","precision","simultaneous","multipliers","arbitrarily","efficiency","decomposes","simultaneously","deviation","dimension","meaningful","applications","consistently","detection","competitive","extraction","inference","variables","discriminant","limitation","dimensionality","supervised","incorporates","classification","semantically","demonstrate","consistent","demonstrates","framework","baselines","reduction","challenging","evaluation","interpret","predictive","hypernetworks","performance","likelihood","distributions","comparable","variational","providing","experiments","uncertainties","distribution","uncertainty","application","experimenting","multispectral","different","validation","facilitate","selection","functions","guidelines","experimentation","management","standardize","associated","recommendations","partitioning","documentation","objective","partitioned","repository","proposals","procedure","annotations","recurrent","questions","outperforms","answering","extensive","significantly","introduce","understanding","generated","uncovering","corresponding","embeddings","respective","subsequently","additional","representation","embedding","performed","separately","modalities","individual","constrained","generative","minimizing","independent","conditional","extracting","extracted","attributes","relationships","probability","distributed","logarithmic","conjunctions","concentrated","separators","appealing","quantities","including","especially","additionally","important","distributional","considering","differential","communication","complexity","perceptron","dependence","fundamental","processes","behavioral","environments","combining","researchers","automated","successful","linguistic","characteristics","information","productive","computational","sequential","techniques","discussion","detecting","interpersonal","collaboration","engagement","participants","contributions","specifically","coordination","interactions","individuals","developed","linguistics","representative","orientation","interaction","characteristically","discussions","collective","combinations","collaborative","influence","contribution","localization","generalization","generalized","convergence","furthermore","characterized","eigenvalues","optimality","processed","constructed","indicated","specialized","publication","approximately","previously","flexibility","exponential","literature","processor","processors","biological","intermediate","modification","requirement","specialization","generically","demonstrated","assumptions","structural","marginals","empirical","minimization","distinguish","hypothesis","adaptation","covariate","restricts","d ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	hypernetworks
# 	newsgroup
# 	acyclicity
# 	robustification
# 	regularizes
# 	distributionally
# 	detectability
# 	embarrassingly
# 	katehakis
# 	terabytes
# 	supernova
# 	epidemics
# 	indiscriminate
# 	factoring
# 	therapies
# 	criterions
# 	notations
# 	minimizers
# 	effectivity
# 	subpopulations
# Some words which never appear in Statistics papers:
# 	digitized
# 	macromolecules
# 	experimenting
# 	standardize
# 	productive
# 	interpersonal
# 	processors
# 	discourse
# 	authorship
# 	upsampling
# 	upsampled
# 	ultrasound
# 	satisfaction
# 	selectional
# 	referential
# 	realistically
# 	reflection
# 	deflection
# 	deformation
# 	monocular

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.074936195073952e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.765
