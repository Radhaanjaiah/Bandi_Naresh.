# %% [markdown]
# <a href="https://colab.research.google.com/github/Radhaanjaiah/fmml_course_assingnment/blob/main/FMML_2022_Module_04_Project_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **FOUNDATIONS OF MODERN MACHINE LEARNING, IIIT Hyderabad**
# ### Project for Module: Perceptron and Gradient Descent
#
# NOTE: YOU NEED TO WRITE CODE IN CELLS THAT SPECIFICALLY MENTION TASK-1, TASK-2, etc.
#
# WRITE ANY OBSERVATION(S), IF REQUIRED BY THE TASK, IN A SEPARATE CELL AT THE BOTTOM OF THE NOTEBOOK.
#
# ---

# %% [markdown]
# # Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm # color map

from sympy import symbols, diff
from math import log

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %% [markdown]
# # Example 1 - A simple cost function
#
# ## $$f(x) = x^2 + x + 1$$

# %%
def f(x):
    return x ** 2 + x + 1

# %%
# Make Data
x_1 = np.linspace(start=-3, stop=3, num=500)

# %%
# Plot
plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_1, f(x_1))
plt.show()

# %% [markdown]
# ## Slope & Derivatives
#
# Creating a function for the derivative of $f(x)$ called df(x)

# %%
def df(x):
    return 2 * x + 1

# %%
# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)

plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
##########################
##########################

## TASK-1 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Gradient Descent
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

x_list = [new_x]
slope_list = [df(new_x)]

for n in range(500):
    previous_x = new_x
    gradient = df(previous_x)  # [REQUIRED]
    new_x = previous_x - step_multiplier * gradient  # [REQUIRED]

    step_size = abs(new_x - previous_x)
    # print(step_size)

    x_list.append(new_x)
    slope_list.append(df(new_x))  # [REQUIRED]

    if step_size < precision:
        print('Loop ran this many times:', n)
        break

print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('f(x) value or cost at this point is:', f(new_x))
# Out:
# Loop ran this many times: 50
# Local minimum occurs at: -0.49996003706460423
# Slope or df(x) value at this point is: 7.992587079153068e-05
# f(x) value or cost at this point is: 0.7500000015970362

# %%
# Superimpose the gradient descent calculations on plot

plt.figure(figsize=[20, 5])

# 1 Chart: Cost function
plt.subplot(1, 3, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3, alpha=0.8)

values = np.array(x_list)
plt.scatter(x_list, f(values), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 3, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(x_list, slope_list, color='red', s=100, alpha=0.5)

# 3 Chart: Derivative (Close Up)
plt.subplot(1, 3, 3)

plt.title('Gradient Descent (close up)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.grid()
plt.xlim(-0.55, -0.2)
plt.ylim(-0.3, 0.8)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=6, alpha=0.8)
plt.scatter(x_list, slope_list, color='red', s=300, alpha=0.6)


plt.show()

# %% [markdown]
# # Example 2 - Multiple Minima vs Initial Guess & Advanced Functions
#
# ## $$g(x) = x^4 - 4x^2 + 5$$

# %%
##########################
##########################

## TASK-2 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return  ## [REQUIRED]

def dg(x):
    return ## [REQUIRED]

# %%
## TASK-3 : Plot function and derivative side by side like has been done earlier

# %% [markdown]
# ## Gradient Descent

# %%
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001,
                    max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# %%
def gradient_descent(derivative_func, initial_guess, multiplier, precision, max_iter=300):
    new_x = initial_guess
    previous_x = 0
    list_x = [new_x]
    deriv_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)

        if gradient is None:
            print("Error: derivative_func returned None.")
            return None, None, None

        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        list_x.append(new_x)
        deriv_list.append(derivative_func(new_x))

        if step_size < precision:
            print('Converged at iteration:', n)
            break

    return new_x, list_x, deriv_list

# Example usage:
local_min, list_x, deriv_list = gradient_descent(dg, 0.5, 0.02, 0.001)
if local_min is not None:
    print('Local min occurs at:', local_min)
    print('Number of steps:', len(list_x))
# Out:
# Error: derivative_func returned None.

# %%
#local_min, list_x, deriv_list = gradient_descent(dg, 0.5, 0.02, 0.001)
#print('Local min occurs at:', local_min)
#print('Number of steps:', len(list_x))

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=-0.5,
                                                 multiplier=0.01, precision=0.0001)
if local_min is not None:

  print('Local min occurs at:', local_min)
  print('Number of steps:', len(list_x))
else:
    print('Gradient descent did not converge.')
# Out:
# Error: derivative_func returned None.
# Gradient descent did not converge.

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=-0.1, multiplier=0.01, precision=0.0001)

if deriv_list is not None:
    print('Local min occurs at:', local_min)
    print('Number of steps:', len(list_x))
else:
    print('Gradient descent did not converge.')
# Out:
# Error: derivative_func returned None.
# Gradient descent did not converge.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the functions g(x) and its derivative dg(x)
def g(x):
    return x**4 - 4*x**2 + 5*x + 1

def dg(x):
    return 4*x**3 - 8*x + 5

# Gradient Descent Function
def gradient_descent(derivative_func, initial_guess, multiplier=0.01, precision=0.0001):
    x = initial_guess
    x_list = [x]
    deriv_list = [derivative_func(x)]

    for _ in range(500):
        x = x - multiplier * derivative_func(x)
        x_list.append(x)
        deriv_list.append(derivative_func(x))

        if abs(deriv_list[-1]) < precision:
            break

    return x, x_list, deriv_list

# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=0)

# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

x_2 = np.linspace(-2, 2, 1000)
plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

# %% [markdown]
# # Example 3 - Divergence and Overflow
#
# ## $$h(x) = x^5 - 2x^4 + 2$$

# %%
## TASK-4 : Code the same things as they were done for the first two examples

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to minimize
def f(x):
    return x**2 + x + 1

# Derivative of the function
def df(x):
    return 2*x + 1

# Gradient Descent Function
def gradient_descent(derivative_func, initial_guess, multiplier=0.01, precision=0.0001):
    x = initial_guess
    x_list = [x]
    deriv_list = [derivative_func(x)]

    for _ in range(500):
        x = x - multiplier * derivative_func(x)
        x_list.append(x)
        deriv_list.append(derivative_func(x))

        if abs(deriv_list[-1]) < precision:
            break

    return x, x_list, deriv_list

# Calling gradient descent

# %% [markdown]
# # The Learning Rate

# %%
# Gradient Descent Function
def gradient_descent(derivative_func, initial_guess, multiplier=0.01, precision=0.0001, max_iter=500):
    x = initial_guess
    x_list = [x]
    deriv_list = [derivative_func(x)]

    for _ in range(max_iter):
        x = x - multiplier * derivative_func(x)
        x_list.append(x)
        deriv_list.append(derivative_func(x))

        if abs(deriv_list[-1]) < precision:
            break

    return x, x_list, deriv_list


# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=1.9, multiplier=0.02, precision=0.0001, max_iter=500)

# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

x_2 = np.linspace(-2, 2, 1000)
plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

print('Number of steps is:', len(list_x))
# Out:
# Number of steps is: 78

# %%
## TASK-5 : Run gradient descent 3 times
## TASK-6 : Plot two more learning rates: mid_gamma (0.001) and high_gamma (0.002)
n = 100
#low_gamma = gradient_descent(derivative_func=dg, initial_guess= 3,
                                                #multiplier=0.0005, precision=0.0001, max_iter=n)


#mid_gamma =## [REQUIRED]
#high_gamma =## [REQUIRED]

# Experiment
#insane_gamma = gradient_descent(derivative_func=dg, initial_guess= 1.9,
                                                #multiplier=0.25, precision=0.0001, max_iter=n)

# %%
## TASK-6 : Plot two more learning rates: mid_gamma (0.001) and high_gamma (0.002)
n = 100

# Function to minimize
def g(x):
    return x**4 - 4*x**2 + 5*x + 1

# Derivative of the function
def dg(x):
    return 4*x**3 - 8*x + 5

# Gradient Descent Function
def gradient_descent(derivative_func, initial_guess, multiplier=0.01, precision=0.0001, max_iter=500):
    x = initial_guess
    x_list = [x]
    deriv_list = [derivative_func(x)]

    for _ in range(max_iter):
        x = x - multiplier * derivative_func(x)
        x_list.append(x)
        deriv_list.append(derivative_func(x))

        if abs(deriv_list[-1]) < precision:
            break

    return x, x_list, deriv_list

# Run gradient descent for different learning rates
local_min_low_gamma, list_x_low_gamma, deriv_list_low_gamma = gradient_descent(derivative_func=dg, initial_guess=1.9, multiplier=0.001, precision=0.0001, max_iter=500)
local_min_mid_gamma, list_x_mid_gamma, deriv_list_mid_gamma = gradient_descent(derivative_func=dg, initial_guess=1.9, multiplier=0.01, precision=0.0001, max_iter=500)
local_min_high_gamma, list_x_high_gamma, deriv_list_high_gamma = gradient_descent(derivative_func=dg, initial_guess=1.9, multiplier=0.002, precision=0.0001, max_iter=500)

# Plot function and derivative for different learning rates
plt.figure(figsize=[15, 10])

# Cost function for low_gamma
plt.subplot(2, 2, 1)
plt.title('Low Gamma - Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x_low_gamma, g(np.array(list_x_low_gamma)), color='red', s=100, alpha=0.6)

# Derivative for low_gamma
plt.subplot(2, 2, 2)
plt.title('Low Gamma - Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x_low_gamma, deriv_list_low_gamma, color='red', s=100, alpha=0.5)

# Cost function for mid_gamma
plt.subplot(2, 2, 3)
plt.title('Mid Gamma - Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x_mid_gamma, g(np.array(list_x_mid_gamma)), color='red', s=100, alpha=0.6)

# Derivative for mid_gamma
plt.subplot(2, 2, 4)
plt.title('Mid Gamma - Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x_mid_gamma, deriv_list_mid_gamma, color='red', s=100, alpha=0.5)

plt.tight_layout()
plt.show()

# Print the results
print('Low Gamma - Number of steps:', len(list_x_low_gamma), '  Local min:', local_min_low_gamma)
print('Mid Gamma - Number of steps:', len(list_x_mid_gamma), '  Local min:', local_min_mid_gamma)
print('High Gamma - Number of steps:', len(list_x_high_gamma), '  Local min:', local_min_high_gamma)
# Out:
# Low Gamma - Number of steps: 501   Local min: 0.8138504161778388
# Mid Gamma - Number of steps: 163   Local min: -1.6593110832023847
# High Gamma - Number of steps: 501   Local min: 0.160103106696663

# %%
## TASK-5 : Run gradient descent 3 times


# Run gradient descent three times with different initial guesses
local_min_1, list_x_1, deriv_list_1 = gradient_descent(derivative_func=dg, initial_guess=1.9, multiplier=0.02, precision=0.0001, max_iter=500)
local_min_2, list_x_2, deriv_list_2 = gradient_descent(derivative_func=dg, initial_guess=-1.5, multiplier=0.02, precision=0.0001, max_iter=500)
local_min_3, list_x_3, deriv_list_3 = gradient_descent(derivative_func=dg, initial_guess=0.5, multiplier=0.02, precision=0.0001, max_iter=500)

# Plot function and derivative for each run
plt.figure(figsize=[15, 15])

# 1st run
plt.subplot(3, 2, 1)
plt.title('Run 1 - Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x_1, g(np.array(list_x_1)), color='red', s=100, alpha=0.6)

plt.subplot(3, 2, 2)
plt.title('Run 1 - Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x_1, deriv_list_1, color='red', s=100, alpha=0.5)

# 2nd run
plt.subplot(3, 2, 3)
plt.title('Run 2 - Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x_2, g(np.array(list_x_2)), color='red', s=100, alpha=0.6)

plt.subplot(3, 2, 4)
plt.title('Run 2 - Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x_2, deriv_list_2, color='red', s=100, alpha=0.5)

# 3rd run
plt.subplot(3, 2, 5)
plt.title('Run 3 - Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x_3, g(np.array(list_x_3)), color='red', s=100, alpha=0.6)

plt.subplot(3, 2, 6)
plt.title('Run 3 - Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x_3, deriv_list_3, color='red', s=100, alpha=0.5)

plt.tight_layout()
plt.show()

# Print the results
print('Run 1 - Number of steps:', len(list_x_1), '  Local min:', local_min_1)
print('Run 2 - Number of steps:', len(list_x_2), '  Local min:', local_min_2)
print('Run 3 - Number of steps:', len(list_x_3), '  Local min:', local_min_3)
# Out:
# Run 1 - Number of steps: 78   Local min: -1.6593104032271004
# Run 2 - Number of steps: 17   Local min: -1.6593110351730063
# Run 3 - Number of steps: 37   Local min: -1.6593114567252671

# %%
## TASK-7 : Plot reduction in cost for each iteration

# Function to minimize
def g(x):
    return x**4 - 4*x**2 + 5*x + 1

# Derivative of the function
def dg(x):
    return 4*x**3 - 8*x + 5

# Gradient Descent Function
def gradient_descent(derivative_func, initial_guess, multiplier=0.01, precision=0.0001, max_iter=500):
    x = initial_guess
    x_list = [x]
    cost_list = [g(x)]

    for _ in range(max_iter):
        x = x - multiplier * derivative_func(x)
        x_list.append(x)
        cost_list.append(g(x))

        if abs(derivative_func(x)) < precision:
            break

    return x_list, cost_list

# Run gradient descent for different learning rates
low_gamma_result = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.0005, precision=0.0001, max_iter=n)
mid_gamma_result = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.001, precision=0.0001, max_iter=n)
high_gamma_result = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.002, precision=0.0001, max_iter=n)

# Plot reduction in cost for each iteration
plt.figure(figsize=[15, 5])

# Low Gamma
plt.subplot(1, 3, 1)
plt.title('Low Gamma - Cost Reduction', fontsize=17)
plt.xlabel('Iteration', fontsize=16)
plt.ylabel('Cost', fontsize=16)
plt.plot(range(len(low_gamma_result[1])), low_gamma_result[1], color='green', marker='o')

# Mid Gamma
plt.subplot(1, 3, 2)
plt.title('Mid Gamma - Cost Reduction', fontsize=17)
plt.xlabel('Iteration', fontsize=16)
plt.ylabel('Cost', fontsize=16)
plt.plot(range(len(mid_gamma_result[1])), mid_gamma_result[1], color='orange', marker='o')

# High Gamma
plt.subplot(1, 3, 3)
plt.title('High Gamma - Cost Reduction', fontsize=17)
plt.xlabel('Iteration', fontsize=16)
plt.ylabel('Cost', fontsize=16)
plt.plot(range(len(high_gamma_result[1])), high_gamma_result[1], color='red', marker='o')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Example 4 - Data Viz with 3D Charts
#
# ## Minimise $$f(x, y) = \frac{1}{3^{-x^2 - y^2} + 1}$$
#
# Minimise $$f(x, y) = \frac{1}{r + 1}$$ where $r$ is $3^{-x^2 - y^2}$

# %%
# Plotting for Low Gamma
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)
plt.title('Low Gamma - Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(low_gamma_result[0], g(np.array(low_gamma_result[0])), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)
plt.title('Low Gamma - Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(low_gamma_result[0], dg(np.array(low_gamma_result[0])), color='red', s=100, alpha=0.5)

plt.tight_layout()
plt.show()

# Plotting for Mid Gamma
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)
plt.title('Mid Gamma - Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(mid_gamma_result[0], g(np.array(mid_gamma_result[0])), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)
plt.title('Mid Gamma - Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(mid_gamma_result[0], dg(np.array(mid_gamma_result[0])), color='red', s=100, alpha=0.5)

plt.tight_layout()
plt.show()

# %%
# Make our x and y data
x_4 = np.linspace(start=-2, stop=2, num=200)
y_4 = np.linspace(start=-2, stop=2, num=200)

print('Shape of X array', x_4.shape)

x_4, y_4 = np.meshgrid(x_4, y_4)
print('Array after meshgrid: ', x_4.shape)
# Out:
# Shape of X array (200,)
# Array after meshgrid:  (200, 200)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# Define the function f(x, y)
def f(x, y):
    return x**2 + y**2  # Example function, replace with your actual function

# Generate data
x_4 = np.linspace(-5, 5, 100)
y_4 = np.linspace(-5, 5, 100)
x_4, y_4 = np.meshgrid(x_4, y_4)
z_4 = f(x_4, y_4)

# Generating 3D Plot
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, z_4, cmap=cm.coolwarm, alpha=0.4)

plt.show()

# %% [markdown]
# ##########################
# ##########################
#
# ## TASK-9 : Complete the lines of text wherever marked as [REQUIRED] in this cell.
#
# ##########################
# ##########################
#
# ## Partial Derivatives & Symbolic Computation
#
# ## $$\frac{\partial f}{\partial x} = ## [REQUIRED]
#
# ## $$\frac{\partial f}{\partial y} = ## [REQUIRED]

# %%
a, b = symbols('x, y')
print('Our cost function f(x, y) is: ', f(a, b))
print('Partial derivative wrt x is: ', diff(f(a, b), b))
print('Value of f(x,y) at x=1.8 y=1.0 is: ',
      f(a, b).evalf(subs={a:1.8, b:1.0})) # Python Dictionary
print('Value of partial derivative wrt x: ', diff(f(a, b), a).evalf(subs={a:1.8, b:1.0}))
# Out:
# Our cost function f(x, y) is:  x**2 + y**2
# Partial derivative wrt x is:  2*y
# Value of f(x,y) at x=1.8 y=1.0 is:  4.24000000000000
# Value of partial derivative wrt x:  3.60000000000000

# %% [markdown]
# ## Batch Gradient Descent with SymPy

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess

for n in range(max_iter):
    gradient_x = diff(f(a, b), a).evalf(subs={a:params[0], b:params[1]})
    gradient_y = diff(f(a, b), b).evalf(subs={a:params[0], b:params[1]})
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# Values in gradient array [1.57835979496953e-48 8.76866552760853e-49]
# Minimum occurs at x value of:  6.31343917987813e-49
# Minimum occurs at y value of:  3.50746621104341e-49
# The cost is:  5.21618334996315e-97

# %%
##########################
##########################

## TASK-10 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Partial derivative functions example 4
def fpx(x, y):
    return ## [REQUIRED]

def fpy(x, y):
    return ## [REQUIRED]

# %%
# Importing NumPy
import numpy as np

# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0])  # initial guess

# Assuming fpx and fpy are functions representing partial derivatives
def fpx(x, y):
    # Replace with your actual partial derivative with respect to x
    return 2 * (x - 2)

def fpy(x, y):
    # Replace with your actual partial derivative with respect to y
    return 2 * (y - 1)

# Assuming f is a function representing the cost
def f(x, y):
    # Replace with your actual cost function
    return (x - 2)**2 + (y - 1)**2

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array:', gradients)
print('Minimum occurs at x value of:', params[0])
print('Minimum occurs at y value of:', params[1])
print('The cost is:', f(params[0], params[1]))
# Out:
# Values in gradient array: [-8.8817842e-16  0.0000000e+00]
# Minimum occurs at x value of: 1.9999999999999996
# Minimum occurs at y value of: 1.0
# The cost is: 1.9721522630525295e-31

# %% [markdown]
# ## Graphing 3D Gradient Descent

# %%
# Setup
multiplier = 0.1
max_iter = 200
params = np.array([1.8, 1.0]) # initial guess
values_array = params.reshape(1, 2)
print(values_array.shape)

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients
    #values_array = np.append(values_array, params.reshape(1, 2), axis=0)
    values_array = np.concatenate((values_array, params.reshape(1, 2)), axis=0)


# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# (1, 2)
# Values in gradient array [-8.8817842e-16  0.0000000e+00]
# Minimum occurs at x value of:  1.9999999999999996
# Minimum occurs at y value of:  1.0
# The cost is:  1.9721522630525295e-31

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# Assuming x_4, y_4, and f are defined
# Replace them with your actual data and function

# Generating data
x_4 = np.linspace(-5, 5, 100)
y_4 = np.linspace(-5, 5, 100)
x_4, y_4 = np.meshgrid(x_4, y_4)

def f(x, y):
    # Replace with your actual cost function
    return x**2 + y**2

# Generate 3D Plot
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)

# Assuming values_array is defined
# Replace it with your actual array of points
values_array = np.array([[1, 2], [2, 3], [3, 4]])

ax.scatter(values_array[:, 0], values_array[:, 1],
           f(values_array[:, 0], values_array[:, 1]), s=50, color='red')

plt.show()

# %% [markdown]
# ## For Reference, practice and play with the code below
#
# # Example 5 - Working with Data & a Real Cost Function
#
# ## Mean Squared Error: a cost function for regression problems
#
# ### $$RSS = \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y - \hat{y} \big)^2 $$

# %%
# Make sample data
x_5 = np.array([[0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7, 1)

print('Shape of x_5 array:', x_5.shape)
print('Shape of y_5 array:', y_5.shape)
# Out:
# Shape of x_5 array: (7, 1)
# Shape of y_5 array: (7, 1)

# %%
# Quick linear regressino
regr = LinearRegression()
regr.fit(x_5, y_5)
print('Theta 0:', regr.intercept_[0])
print('Theta 1:', regr.coef_[0][0])
# Out:
# Theta 0: 0.8475351486029545
# Theta 1: 1.2227264637835913

# %%
plt.scatter(x_5, y_5, s=50)
plt.plot(x_5, regr.predict(x_5), color='orange', linewidth=3)
plt.xlabel('x values')
plt.ylabel('y values')
plt.show()

# %%
# y_hat = theta0 + theta1*x
y_hat = 0.847535148603 + 1.22272646378*x_5
print('Est values y_hat are: \n', y_hat)
print('In comparison, the actual y values are \n', y_5)
# Out:
# Est values y_hat are:
#  [[0.96980779]
#  [2.31480691]
#  [3.78207866]
#  [4.76025983]
#  [5.86071365]
#  [7.81707599]
#  [8.79525716]]
# In comparison, the actual y values are
#  [[1.7]
#  [2.4]
#  [3.5]
#  [3. ]
#  [6.1]
#  [9.4]
#  [8.2]]

# %%
# Challenge: Write a python function mse(y, y_hat) returns the MSE? Call the mse(y, y_hat)
# function and print out the MSE for the y_hat calculated above.

def mse(y, y_hat):
    #mse_calc = 1/7 * sum((y - y_hat)**2)
    #mse_calc = (1/y.size) * sum((y - y_hat)**2)
    mse_calc = np.average((y - y_hat)**2, axis=0)
    return mse_calc

# %%
print('Manually calculated MSE is:', mse(y_5, y_hat))
print('MSE regression using manual calc is', mean_squared_error(y_5, y_hat))
print('MSE regression is', mean_squared_error(y_5, regr.predict(x_5)))
# Out:
# Manually calculated MSE is: [0.94796558]
# MSE regression using manual calc is 0.947965575979458
# MSE regression is 0.9479655759794577

# %% [markdown]
# ## 3D Plot for the MSE Cost Function
#
# ### Make data for thetas

# %%
nr_thetas = 200
th_0 = np.linspace(start=-1, stop=3, num=nr_thetas)
th_1 = np.linspace(start=-1, stop=3, num=nr_thetas)
plot_t0, plot_t1 = np.meshgrid(th_0, th_1)

# %% [markdown]
# ### Calc MSE using nested for loops

# %%
plot_cost = np.zeros((nr_thetas, nr_thetas))

for i in range(nr_thetas):
    for j in range(nr_thetas):
        #print(plot_t0[j][i])
        y_hat = plot_t0[i][j] + plot_t1[i][j]*x_5
        plot_cost[i][j] = mse(y_5, y_hat)

print('Shape of plot_t0', plot_t0.shape)
print('Shape of plot_t1', plot_t1.shape)
print('Shape of plot_cost', plot_cost.shape)
# Out:
# Shape of plot_t0 (200, 200)
# Shape of plot_t1 (200, 200)
# Shape of plot_cost (200, 200)

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.hot)
plt.show()

# %%
print('Min value of plot_cost', plot_cost.min())
ij_min = np.unravel_index(plot_cost.argmin(), plot_cost.shape)
print('Min occurs at (i,j):', ij_min)
print('Min MSE for Theta 0 at plot_t0[111][91]', plot_t0[ij_min[0]][ij_min[1]])
print('Min MSE for Theta 1 at plot_t1[111][91]', plot_t1[ij_min[0]][ij_min[1]])
# Out:
# Min value of plot_cost 0.9483826526747164
# Min occurs at (i,j): (111, 91)
# Min MSE for Theta 0 at plot_t0[111][91] 0.829145728643216
# Min MSE for Theta 1 at plot_t1[111][91] 1.2311557788944723

# %% [markdown]
# ## Partial Derivatives of MSE w.r.t. $\theta_0$ and $\theta_1$
#
# ## $$\frac{\partial MSE}{\partial \theta_0} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big)$$
#
# ## $$\frac{\partial MSE}{\partial \theta_1} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big) \big( x^{(i)} \big)$$

# %% [markdown]
# ## MSE & Gradient Descent

# %%
# x values, y values, array of theta parameters (theta0 at index 0 and theta1 at index 1)
def grad(x, y, thetas):
    n = y.size

    # Challenge: Create theta0_slope and theta1_slope to hold slope values from partial derivs
    theta0_slope = (-2/n) * sum(y - thetas[0] - thetas[1]*x)
    theta1_slope = (-2/n) * sum((y - thetas[0] - thetas[1]*x)*x)

    #return np.array([theta0_slope[0], theta1_slope[0]])
    #return np.append(arr=theta0_slope, values=theta1_slope)
    return np.concatenate((theta0_slope, theta1_slope), axis=0)

# %%
multiplier = 0.01
thetas = np.array([2.9, 2.9])

# Collect data points for scatter plot
plot_vals = thetas.reshape(1, 2)
mse_vals = mse(y_5, thetas[0] + thetas[1]*x_5)

for i in range(1000):
    thetas = thetas - multiplier * grad(x_5, y_5, thetas)

    # Append the new values to our numpy arrays
    plot_vals = np.concatenate((plot_vals, thetas.reshape(1, 2)), axis=0)
    mse_vals = np.append(arr=mse_vals, values=mse(y_5, thetas[0] + thetas[1]*x_5))

# Results
print('Min occurs at Theta 0:', thetas[0])
print('Min occurs at Theta 1:', thetas[1])
print('MSE is:', mse(y_5, thetas[0] + thetas[1]*x_5))
# Out:
# Min occurs at Theta 0: 0.8532230461743415
# Min occurs at Theta 1: 1.2214935332607393
# MSE is: [0.94797511]

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.scatter(plot_vals[:, 0], plot_vals[:, 1], mse_vals, s=80, color='black')
ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.rainbow, alpha=0.4)
plt.show()
